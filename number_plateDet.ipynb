# %% [markdown]
# <a href="https://colab.research.google.com/github/Amar1701/DataScienceIntern/blob/main/number_plateDet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install easyocr
# !pip install imutils
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 37.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 53.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 35.6 MB/s eta 0:00:00
# ...

# %%
import cv2
import easyocr
import pandas as pd
from datetime import datetime

# Load the EasyOCR model with the desired language(s)
reader = easyocr.Reader(['en'])  # 'en' for English; you can add more languages if needed

# Initialize variables for tracking entry and exit times
entry_times = {}
exit_times = {}

# Open the default camera (index 0)
cap = cv2.VideoCapture(0)

# Initialize an empty list to store the recognized text
recognized_text_list = []

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Extract license plate region from the frame
    cropped_license_plate, plate_location = extract_license_plate(frame)

    # Perform OCR on the cropped license plate image
    result = reader.readtext(cropped_license_plate)

    # Extract the recognized text from the OCR results
    recognized_text = [detection[1] for detection in result]

    # Save the recognized text to the list
    recognized_text_list.extend(recognized_text)

    # Check if the recognized text is not empty
    if recognized_text:
        plate_number = recognized_text[0]
        # Check if the car is entering or exiting
        if plate_number not in entry_times:
            # Car is entering
            entry_times[plate_number] = datetime.now()
            print(f"Car with plate number {plate_number} entered at {entry_times[plate_number]}")
        else:
            # Car is exiting
            exit_times[plate_number] = datetime.now()
            entry_time = entry_times[plate_number]
            exit_time = exit_times[plate_number]

            # Calculate parking duration in hours
            duration = (exit_time - entry_time).total_seconds() / 3600

            # Calculate parking charge (assuming minimum charge is Rs. 20 per hour)
            parking_charge = max(20, round(duration) * 20)

            print(f"Car with plate number {plate_number} exited at {exit_time}")
            print(f"Parking duration: {duration:.2f} hours")
            print(f"Parking charge: Rs. {parking_charge:.2f}")

    # Display the frame with license plate information (optional)
    cv2.imshow("Live Parking System", frame)

    # Check for the 'q' key to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
cap.release()
# Destroy any open CV2 windows
cv2.destroyAllWindows()
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import cv2
import easyocr
import pandas as pd
from datetime import datetime
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# Load the EasyOCR model with the desired language(s)
reader = easyocr.Reader(['en'])  # 'en' for English; you can add more languages if needed

# Initialize variables for tracking entry and exit times
entry_times = {}
exit_times = {}

# Function to extract license plate regions from a frame
def extract_license_plate(frame):
    # ... (your existing code for license plate extraction)
    import cv2
import easyocr
import pandas as pd
from datetime import datetime

# Load the EasyOCR model with the desired language(s)
reader = easyocr.Reader(['en'])  # 'en' for English; you can add more languages if needed

# Initialize variables for tracking entry and exit times
entry_times = {}
exit_times = {}

# Open the default camera (index 0)
cap = cv2.VideoCapture(0)

# Initialize an empty list to store the recognized text
recognized_text_list = []

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Extract license plate region from the frame
    cropped_license_plate, plate_location = extract_license_plate(frame)

    # Perform OCR on the cropped license plate image
    result = reader.readtext(cropped_license_plate)

    # Extract the recognized text from the OCR results
    recognized_text = [detection[1] for detection in result]

    # Save the recognized text to the list
    recognized_text_list.extend(recognized_text)

    # Check if the recognized text is not empty
    if recognized_text:
        plate_number = recognized_text[0]
        # Check if the car is entering or exiting
        if plate_number not in entry_times:
            # Car is entering
            entry_times[plate_number] = datetime.now()
            print(f"Car with plate number {plate_number} entered at {entry_times[plate_number]}")
        else:
            # Car is exiting
            exit_times[plate_number] = datetime.now()
            entry_time = entry_times[plate_number]
            exit_time = exit_times[plate_number]

            # Calculate parking duration in hours
            duration = (exit_time - entry_time).total_seconds() / 3600

            # Calculate parking charge (assuming minimum charge is Rs. 20 per hour)
            parking_charge = max(20, round(duration) * 20)

            print(f"Car with plate number {plate_number} exited at {exit_time}")
            print(f"Parking duration: {duration:.2f} hours")
            print(f"Parking charge: Rs. {parking_charge:.2f}")

    # Display the frame with license plate information (optional)
    cv2.imshow("Live Parking System", frame)

    # Check for the 'q' key to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture object
cap.release()
# Destroy any open CV2 windows
cv2.destroyAllWindows()


# Function to update the GUI with information
def update_gui(plate_number, entry_time, exit_time, duration, parking_charge):
    info_text.set(f"Plate Number: {plate_number}\nEntry Time: {entry_time}\nExit Time: {exit_time}\n"
                  f"Parking Duration: {duration:.2f} hours\nParking Charge: Rs. {parking_charge:.2f}")

# Function to process frames in the video stream
def process_frame():
    ret, frame = cap.read()
    if ret:
        # Extract license plate region from the frame
        cropped_license_plate, plate_location = extract_license_plate(frame)

        # Perform OCR on the cropped license plate image
        result = reader.readtext(cropped_license_plate)

        # Extract the recognized text from the OCR results
        recognized_text = [detection[1] for detection in result]

        # Save the recognized text to the list
        recognized_text_list.extend(recognized_text)

        # Check if the recognized text is not empty
        if recognized_text:
            plate_number = recognized_text[0]
            # Check if the car is entering or exiting
            if plate_number not in entry_times:
                # Car is entering
                entry_times[plate_number] = datetime.now()
                entry_time_str = entry_times[plate_number].strftime('%Y-%m-%d %H:%M:%S')
                print(f"Car with plate number {plate_number} entered at {entry_time_str}")
                messagebox.showinfo("Car Entered", f"Car with plate number {plate_number} entered at {entry_time_str}")
            else:
                # Car is exiting
                exit_times[plate_number] = datetime.now()
                entry_time = entry_times[plate_number]
                exit_time = exit_times[plate_number]

                # Calculate parking duration in hours
                duration = (exit_time - entry_time).total_seconds() / 3600

                # Calculate parking charge (assuming minimum charge is Rs. 20 per hour)
                parking_charge = max(20, round(duration) * 20)

                exit_time_str = exit_time.strftime('%Y-%m-%d %H:%M:%S')
                print(f"Car with plate number {plate_number} exited at {exit_time_str}")
                print(f"Parking duration: {duration:.2f} hours")
                print(f"Parking charge: Rs. {parking_charge:.2f}")

                # Update the GUI with information
                update_gui(plate_number, entry_time_str, exit_time_str, duration, parking_charge)

        # Convert the frame to RGB for displaying in Tkinter
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(frame_rgb)
        img = ImageTk.PhotoImage(img)
        panel.img = img
        panel.config(image=img)

        # Schedule the next frame processing
        root.after(10, process_frame)

# Create the main Tkinter window
root = tk.Tk()
root.title("Car Parking System")

# Create a label to display the video stream
panel = tk.Label(root)
panel.pack(padx=10, pady=10)

# Create a variable to store information text
info_text = tk.StringVar()
info_label = tk.Label(root, textvariable=info_text, font=('Helvetica', 12))
info_label.pack(pady=10)

# Open the default camera (index 0)
cap = cv2.VideoCapture(0)

# Initialize an empty list to store the recognized text
recognized_text_list = []

# Start processing the video stream
process_frame()

# Run the Tkinter event loop
root.mainloop()

# Release the video capture object when the window is closed
cap.release()
